# %% [markdown]
# # Instrument Lineshapes
#
# MATS has added the capability to simulate and fit spectra using an instrument lineshape.  MATS automatically loads the slit functions defined in HAPI, but could use any slit function with the form slit_function(x, resolution) or slit_function(x, [resolutions]).  MATS uses a slight variation of the HAPI convolveSpectrumSame, where the arange_ function was redefined to address a integer/float bug in the underlying np.linspace call.  This implementation currently assumes an equal wavenumber spacing.
#
# The example below simulates the same spectrum and applies the different HAPI instrument line shapes.  The simulated molefraction is perturbted and then floated during a fit.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
from scipy import interpolate
import seaborn as sns

# %matplotlib inline
import MATS
# Out:
# HAPI version: 1.3.0.0
# To get the most up-to-date version please check http://hitran.org/hapi
# ATTENTION: Python versions of partition sums from TIPS-2021 are now available in HAPI code
#
#            MIT license: Copyright 2021 HITRAN team, see more at http://hitran.org.
#
#            If you use HAPI in your research or software development,
#            please cite it using the following reference:
#            R.V. Kochanov, I.E. Gordon, L.S. Rothman, P. Wcislo, C. Hill, J.S. Wilzewski,
#            HITRAN Application Programming Interface (HAPI): A comprehensive approach
#            to working with spectroscopic data, J. Quant. Spectrosc. Radiat. Transfer 177, 15-30 (2016)
#            DOI: 10.1016/j.jqsrt.2016.03.005
#
#            ATTENTION: This is the core version of the HITRAN Application Programming Interface.
#                       For more efficient implementation of the absorption coefficient routine,
#                       as well as for new profiles, parameters and other functional,
#                       please consider using HAPI2 extension library.
#                       HAPI2 package is available at http://github.com/hitranonline/hapi2

# %% [markdown]
# ## Simulate Spectra with ILS
#
# The spectrum object definitions show how to use the ILS_function, ILS_resolution, and ILS_wing (defines the length of the ILS slit function to use in the convolution, such that the length is +/- ILS_wing / spectrum stepsize) to define the ILS function.  The outputs below show the generated spectrum for each ILS_function

# %%
from MATS.linelistdata import linelistdata
import MATS.hapi as hapi

# %%
# Shared Simulation and Fit Parameters
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
Fit_Intensity = 1e-24#intensities must be above this value for the line to be fit
wave_range = 1.5 #range outside of experimental x-range to simulate
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
segment_column = None
order_baseline_fit = 1
etalon = {}
SNR = 5000
resolution = 0.25
molefraction = {2:0.01}
wave_min = 6320
wave_max = 6340
wave_step = 0.01
pressure = 0.2
temperature = 296


PARAM_LINELIST = linelistdata['CO2_30012']
PARAM_LINELIST = PARAM_LINELIST[(PARAM_LINELIST['nu'] <= wave_max + wave_range) & (PARAM_LINELIST['nu']>= wave_min - wave_step)]
PARAM_LINELIST['nuOptRe_air']=PARAM_LINELIST['nuVC_air']
PARAM_LINELIST['n_nuOptRe_air']=PARAM_LINELIST['n_nuVC_air']
PARAM_LINELIST['nuOptIm_air']=0
PARAM_LINELIST['n_nuOptIm_air']=0


# Simulate Spectra
spec_rectangular =  MATS.simulate_spectrum(PARAM_LINELIST, wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  
                                pressure = pressure, 
                                 filename = 'Rectangular', 
                               molefraction =  {2:0.01} , ILS_function = hapi.SLIT_RECTANGULAR, ILS_resolution = resolution, ILS_wing = 10)
spec_triangular=  MATS.simulate_spectrum(PARAM_LINELIST,  wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  pressure = pressure, 
                                 filename = 'Triangular', 
                               molefraction =  {2:0.01}, ILS_function = hapi.SLIT_TRIANGULAR, ILS_resolution = resolution, ILS_wing = 10)
spec_gaussian =  MATS.simulate_spectrum(PARAM_LINELIST,  wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  pressure = pressure,
                                 filename = 'Gaussian', 
                               molefraction =  {2:0.01}, ILS_function = hapi.SLIT_GAUSSIAN, ILS_resolution = resolution, ILS_wing = 10)
spec_dispersion =  MATS.simulate_spectrum(PARAM_LINELIST,  wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  pressure = pressure,
                                 filename = 'Dispersion', 
                               molefraction =  {2:0.01}, ILS_function = hapi.SLIT_DISPERSION, ILS_resolution = resolution, ILS_wing = 10)
spec_cosinus =  MATS.simulate_spectrum(PARAM_LINELIST,  wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  pressure = pressure,
                                 filename = 'Cosinus', 
                               molefraction =  {2:0.01}, ILS_function = hapi.SLIT_COSINUS, ILS_resolution = resolution, ILS_wing = 10)
spec_diffraction =  MATS.simulate_spectrum(PARAM_LINELIST,  wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  pressure = pressure,
                                 filename = 'Diffraction', 
                               molefraction =  {2:0.01}, ILS_function = hapi.SLIT_DIFFRACTION, ILS_resolution = resolution, ILS_wing = 10)
spec_michelson =  MATS.simulate_spectrum(PARAM_LINELIST,  wave_min= wave_min, wave_max= wave_max, wave_space = wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = temperature,  pressure = pressure,
                                 filename = 'Michelson', 
                               molefraction =  {2:0.01}, ILS_function = hapi.SLIT_MICHELSON, ILS_resolution = resolution, ILS_wing = 10)
print ('Rectangular')
spec_rectangular.plot_wave_y()
print ('Triangular')
spec_triangular.plot_wave_y()
print ('Gaussian')
spec_gaussian.plot_wave_y()
print ('Dispersion')
spec_dispersion.plot_wave_y()
print ('Cosinus')
spec_cosinus.plot_wave_y()
print ('Diffraction')
spec_diffraction.plot_wave_y()
print ('Michelson')
spec_michelson.plot_wave_y()
# Out:
# Rectangular
# Triangular
# Gaussian
# Dispersion
# Cosinus
# Diffraction
# Michelson

# %% [markdown]
# ## Generate Fit Parameters
#
# The CO2 molefraction is perturbed from the initial guess. Normally distributed 2% random uncertainy put on the initial mole fraction guess.
#
# In addition to the normal line shape and baseline parameters the ILS resolution parameters are also fittable parameters.  This is also coded in such a way that different spectra can have different ILS functions and the baseline linelist table adequately accounts for this.  While floating the resolution parameters is possible, it should be done with caution as all other parameters are dependent on this value, so correlation and poor fits are likely.

# %%
SPECTRA = MATS.Dataset([ spec_rectangular, spec_triangular, spec_gaussian, spec_dispersion, spec_cosinus, 
                               spec_diffraction, spec_michelson],  'ILS Study', PARAM_LINELIST) 
BASE_LINELIST = SPECTRA.generate_baseline_paramlist()

BASE_LINELIST['molefraction_CO2'] = BASE_LINELIST['molefraction_CO2'].values*(1 + np.random.normal(loc = 0, scale =1, size = len(BASE_LINELIST['molefraction_CO2']))*(2/100)) #Adjust the mole fraction of each sample by a mole fraction of random value normally distributed 2%




FITPARAMS = MATS.Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST,
                                           lineprofile = 'SDNGP', linemixing = True, 
                                              fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, 
                                              nu_constrain = True, sw_constrain = True, gamma0_constrain = True, delta0_constrain = True, 
                                               aw_constrain = True, as_constrain = True, 
                                               nuOptRe_constrain = True, nuOptIm_constrain =True, linemixing_constrain = True) 


FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {2:{1:False, 2:False, 3:False}}, vary_sw = {2:{1:False, 2:False, 3:False}},
                                                    vary_gamma0 = {2:{1: False, 2:False, 3: False}}, vary_n_gamma0 = {2:{1:False}}, 
                                                    vary_delta0 = {2:{1:False, 2:False, 3: False}}, vary_n_delta0 = {2:{1:False}}, 
                                                    vary_aw = {2:{1: False, 2:False, 3: False}}, vary_n_gamma2 = {2:{1:False}}, 
                                                    vary_as = {2:{1:False}}, vary_n_delta2 = {2:{1:False}}, 
                                                    vary_nuOptRe = {2:{1:False}}, vary_n_nuOptRe = {2:{1:False}},
                                                    vary_nuOptIm = {}, vary_linemixing = {2:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = False, vary_molefraction = {2:True}, vary_ILS_res = False)
# Out:
#                  Segment Number  Pressure  Pressure_err  Pressure_vary  \
# Spectrum Number
# 1                             1       0.2           0.0          False
# 2                             1       0.2           0.0          False
# 3                             1       0.2           0.0          False
# 4                             1       0.2           0.0          False
# 5                             1       0.2           0.0          False
# 6                             1       0.2           0.0          False
# 7                             1       0.2           0.0          False
#
#                  Temperature  Temperature_err  Temperature_vary  x_shift  \
# Spectrum Number
# 1                      296.0              0.0             False      0.0
# 2                      296.0              0.0             False      0.0
# 3                      296.0              0.0             False      0.0
# 4                      296.0              0.0             False      0.0
# 5                      296.0              0.0             False      0.0
# 6                      296.0              0.0             False      0.0
# 7                      296.0              0.0             False      0.0
#
#                  x_shift_err  x_shift_vary  ...  SLIT_DISPERSION_res_0_vary  \
# Spectrum Number                             ...
# 1                        0.0         False  ...                       False
# 2                        0.0         False  ...                       False
# 3                        0.0         False  ...                       False
# 4                        0.0         False  ...                       False
# 5                        0.0         False  ...                       False
# 6                        0.0         False  ...                       False
# 7                        0.0         False  ...                       False
#
#                  SLIT_COSINUS_res_0  SLIT_COSINUS_res_0_err  \
# Spectrum Number
# 1                              0.00                     0.0
# 2                              0.00                     0.0
# 3                              0.00                     0.0
# 4                              0.00                     0.0
# 5                              0.25                     0.0
# 6                              0.00                     0.0
# 7                              0.00                     0.0
#
#                  SLIT_COSINUS_res_0_vary  SLIT_DIFFRACTION_res_0  \
# Spectrum Number
# 1                                  False                    0.00
# 2                                  False                    0.00
# 3                                  False                    0.00
# 4                                  False                    0.00
# 5                                  False                    0.00
# 6                                  False                    0.25
# 7                                  False                    0.00
#
#                  SLIT_DIFFRACTION_res_0_err  SLIT_DIFFRACTION_res_0_vary  \
# Spectrum Number
# 1                                       0.0                        False
# 2                                       0.0                        False
# 3                                       0.0                        False
# 4                                       0.0                        False
# 5                                       0.0                        False
# 6                                       0.0                        False
# 7                                       0.0                        False
#
#                  SLIT_MICHELSON_res_0  SLIT_MICHELSON_res_0_err  \
# Spectrum Number
# 1                                0.00                       0.0
# 2                                0.00                       0.0
# 3                                0.00                       0.0
# 4                                0.00                       0.0
# 5                                0.00                       0.0
# 6                                0.00                       0.0
# 7                                0.25                       0.0
#
#                  SLIT_MICHELSON_res_0_vary
# Spectrum Number
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# 7                                    False
#
# [7 rows x 37 columns]

# %% [markdown]
# # Fit Data
#
# The data is fit floating only the molefraction for each of spectrum.  We can then look at the uncertainty in the molefraction for each of the ILS functions in this synthetic example.  Note the result is for one iteration.

# %%
fit_data = MATS.Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity)
params = fit_data.generate_params()
for param in params:
    if ('_res_' in param) and (params[param].vary == True):
        params[param].set(min = 0.01)
        
result = fit_data.fit_data(params)
print (result.params.pretty_print())
fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
# Out:
# Name                           Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_1                     0.2     -inf      inf        0    False     None     None
# Pressure_2_1                     0.2     -inf      inf        0    False     None     None
# Pressure_3_1                     0.2     -inf      inf        0    False     None     None
# Pressure_4_1                     0.2     -inf      inf        0    False     None     None
# Pressure_5_1                     0.2     -inf      inf        0    False     None     None
# Pressure_6_1                     0.2     -inf      inf        0    False     None     None
# Pressure_7_1                     0.2     -inf      inf        0    False     None     None
# SD_delta_air_line_1014             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1066             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1112             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1158             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1203             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1249             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1301             0     -inf      inf        0    False     None     None
# SD_delta_air_line_1350             0     -inf      inf        0    False     None     None
# SD_delta_air_line_799              0     -inf      inf        0    False     None     None
# SD_delta_air_line_862              0     -inf      inf        0    False     None     None
# SD_delta_air_line_918              0     -inf      inf        0    False     None     None
# SD_delta_air_line_966              0     -inf      inf        0    False     None     None
# SD_gamma_air_line_1014       0.07147     -inf      inf        0    False     None     None
# SD_gamma_air_line_1066       0.07147     -inf      inf        0    False     None     None
# SD_gamma_air_line_1112       0.06883     -inf      inf        0    False     None     None
# SD_gamma_air_line_1158       0.07677     -inf      inf        0    False     None     None
# SD_gamma_air_line_1203       0.07941     -inf      inf        0    False     None     None
# SD_gamma_air_line_1249       0.08206     -inf      inf        0    False     None     None
# SD_gamma_air_line_1301       0.07941     -inf      inf        0    False     None     None
# SD_gamma_air_line_1350       0.07941     -inf      inf        0    False     None     None
# SD_gamma_air_line_799        0.06883     -inf      inf        0    False     None     None
# SD_gamma_air_line_862        0.06088     -inf      inf        0    False     None     None
# SD_gamma_air_line_918        0.05559     -inf      inf        0    False     None     None
# SD_gamma_air_line_966        0.07412     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_1_1             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_2_1             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_3_1             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_4_1             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_5_1          0.25     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_6_1             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_7_1             0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_1_1         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_2_1         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_3_1         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_4_1         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_5_1         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_6_1      0.25     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_7_1         0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_1_1          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_2_1          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_3_1          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_4_1       0.25     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_5_1          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_6_1          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_7_1          0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_1_1            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_2_1            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_3_1         0.25     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_4_1            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_5_1            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_6_1            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_7_1            0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_1_1           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_2_1           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_3_1           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_4_1           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_5_1           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_6_1           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_7_1        0.25     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_1_1      0.25     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_2_1         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_3_1         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_4_1         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_5_1         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_6_1         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_7_1         0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_1_1          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_2_1       0.25     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_3_1          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_4_1          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_5_1          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_6_1          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_7_1          0     -inf      inf        0    False     None     None
# Temperature_1_1                  296     -inf      inf        0    False     None     None
# Temperature_2_1                  296     -inf      inf        0    False     None     None
# Temperature_3_1                  296     -inf      inf        0    False     None     None
# Temperature_4_1                  296     -inf      inf        0    False     None     None
# Temperature_5_1                  296     -inf      inf        0    False     None     None
# Temperature_6_1                  296     -inf      inf        0    False     None     None
# Temperature_7_1                  296     -inf      inf        0    False     None     None
# baseline_a_1_1                     0     -inf      inf        0    False     None     None
# baseline_a_2_1                     0     -inf      inf        0    False     None     None
# baseline_a_3_1                     0     -inf      inf        0    False     None     None
# baseline_a_4_1                     0     -inf      inf        0    False     None     None
# baseline_a_5_1                     0     -inf      inf        0    False     None     None
# baseline_a_6_1                     0     -inf      inf        0    False     None     None
# baseline_a_7_1                     0     -inf      inf        0    False     None     None
# delta0_air_line_1014        -0.007098     -inf      inf        0    False     None     None
# delta0_air_line_1066        -0.006591     -inf      inf        0    False     None     None
# delta0_air_line_1112        -0.006286     -inf      inf        0    False     None     None
# delta0_air_line_1158        -0.006185     -inf      inf        0    False     None     None
# delta0_air_line_1203        -0.006084     -inf      inf        0    False     None     None
# delta0_air_line_1249        -0.006016     -inf      inf        0    False     None     None
# delta0_air_line_1301        -0.005813     -inf      inf        0    False     None     None
# delta0_air_line_1350        -0.005408     -inf      inf        0    False     None     None
# delta0_air_line_799         -0.006793     -inf      inf        0    False     None     None
# delta0_air_line_862         -0.006489     -inf      inf        0    False     None     None
# delta0_air_line_918         -0.006286     -inf      inf        0    False     None     None
# delta0_air_line_966         -0.006388     -inf      inf        0    False     None     None
# gamma0_air_line_1014         0.07199     -inf      inf        0    False     None     None
# gamma0_air_line_1066         0.07311     -inf      inf        0    False     None     None
# gamma0_air_line_1112         0.07429     -inf      inf        0    False     None     None
# gamma0_air_line_1158         0.07581     -inf      inf        0    False     None     None
# gamma0_air_line_1203         0.07689     -inf      inf        0    False     None     None
# gamma0_air_line_1249         0.07889     -inf      inf        0    False     None     None
# gamma0_air_line_1301          0.0803     -inf      inf        0    False     None     None
# gamma0_air_line_1350         0.08179     -inf      inf        0    False     None     None
# gamma0_air_line_799          0.06979     -inf      inf        0    False     None     None
# gamma0_air_line_862           0.0706     -inf      inf        0    False     None     None
# gamma0_air_line_918          0.07071     -inf      inf        0    False     None     None
# gamma0_air_line_966          0.07142     -inf      inf        0    False     None     None
# molefraction_CO2_1_1            0.01     -inf      inf 1.595e-07     True     None     None
# molefraction_CO2_2_1            0.01     -inf      inf 1.829e-07     True     None     None
# molefraction_CO2_3_1            0.01     -inf      inf 1.834e-07     True     None     None
# molefraction_CO2_4_1            0.01     -inf      inf 2.482e-07     True     None     None
# molefraction_CO2_5_1            0.01     -inf      inf 4.72e-07     True     None     None
# molefraction_CO2_6_1            0.01     -inf      inf 1.843e-07     True     None     None
# molefraction_CO2_7_1            0.01     -inf      inf 1.18e-07     True     None     None
# nuOptIm_air_line_1014              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1066              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1112              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1158              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1203              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1249              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1301              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_1350              0     -inf      inf        0    False     None     None
# nuOptIm_air_line_799               0     -inf      inf        0    False     None     None
# nuOptIm_air_line_862               0     -inf      inf        0    False     None     None
# nuOptIm_air_line_918               0     -inf      inf        0    False     None     None
# nuOptIm_air_line_966               0     -inf      inf        0    False     None     None
# nuOptRe_air_line_1014       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1066       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1112       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1158       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1203       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1249       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1301       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_1350       0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_799        0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_862        0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_918        0.003099     -inf      inf        0    False     None     None
# nuOptRe_air_line_966        0.003099     -inf      inf        0    False     None     None
# nu_line_1014                    6329     -inf      inf        0    False     None     None
# nu_line_1066                    6331     -inf      inf        0    False     None     None
# nu_line_1112                    6333     -inf      inf        0    False     None     None
# nu_line_1158                    6334     -inf      inf        0    False     None     None
# nu_line_1203                    6336     -inf      inf        0    False     None     None
# nu_line_1249                    6338     -inf      inf        0    False     None     None
# nu_line_1301                    6340     -inf      inf        0    False     None     None
# nu_line_1350                    6341     -inf      inf        0    False     None     None
# nu_line_799                     6321     -inf      inf        0    False     None     None
# nu_line_862                     6323     -inf      inf        0    False     None     None
# nu_line_918                     6325     -inf      inf        0    False     None     None
# nu_line_966                     6327     -inf      inf        0    False     None     None
# sw_line_1014                    14.1     -inf      inf        0    False     None     None
# sw_line_1066                    15.2     -inf      inf        0    False     None     None
# sw_line_1112                    15.9     -inf      inf        0    False     None     None
# sw_line_1158                    16.2     -inf      inf        0    False     None     None
# sw_line_1203                      16     -inf      inf        0    False     None     None
# sw_line_1249                    15.2     -inf      inf        0    False     None     None
# sw_line_1301                    13.9     -inf      inf        0    False     None     None
# sw_line_1350                      12     -inf      inf        0    False     None     None
# sw_line_799                     8.47     -inf      inf        0    False     None     None
# sw_line_862                     9.94     -inf      inf        0    False     None     None
# sw_line_918                     11.4     -inf      inf        0    False     None     None
# sw_line_966                     12.9     -inf      inf        0    False     None     None
# x_shift_1_1                        0     -inf      inf        0    False     None     None
# x_shift_2_1                        0     -inf      inf        0    False     None     None
# x_shift_3_1                        0     -inf      inf        0    False     None     None
# x_shift_4_1                        0     -inf      inf        0    False     None     None
# x_shift_5_1                        0     -inf      inf        0    False     None     None
# x_shift_6_1                        0     -inf      inf        0    False     None     None
# x_shift_7_1                        0     -inf      inf        0    False     None     None
# y_air_line_1014                    0     -inf      inf        0    False     None     None
# y_air_line_1066                    0     -inf      inf        0    False     None     None
# y_air_line_1112                    0     -inf      inf        0    False     None     None
# y_air_line_1158                    0     -inf      inf        0    False     None     None
# y_air_line_1203                    0     -inf      inf        0    False     None     None
# y_air_line_1249                    0     -inf      inf        0    False     None     None
# y_air_line_1301                    0     -inf      inf        0    False     None     None
# y_air_line_1350                    0     -inf      inf        0    False     None     None
# y_air_line_799                     0     -inf      inf        0    False     None     None
# y_air_line_862                     0     -inf      inf        0    False     None     None
# y_air_line_918                     0     -inf      inf        0    False     None     None
# y_air_line_966                     0     -inf      inf        0    False     None     None
# None
#        Spectrum Number Spectrum Name  Wavenumber (cm-1)  Pressure (atm)  \
# 0                    1   Rectangular            6320.00             0.2
# 1                    1   Rectangular            6320.01             0.2
# 2                    1   Rectangular            6320.02             0.2
# 3                    1   Rectangular            6320.03             0.2
# 4                    1   Rectangular            6320.04             0.2
# ...                ...           ...                ...             ...
# 14009                7     Michelson            6339.97             0.2
# 14010                7     Michelson            6339.98             0.2
# 14011                7     Michelson            6339.99             0.2
# 14012                7     Michelson            6340.00             0.2
# 14013                7     Michelson            6340.01             0.2
#
#        Temperature (K)  alpha (10^-6 cm^-1)  Model (10^-6 cm^-1)  \
# 0                296.0             0.030996             0.030708
# 1                296.0             0.036669             0.036232
# 2                296.0             0.039872             0.039824
# 3                296.0             0.043545             0.042205
# 4                296.0             0.044855             0.044428
# ...                ...                  ...                  ...
# 14009            296.0             0.149892             0.150946
# 14010            296.0             0.300335             0.300497
# 14011            296.0             0.427851             0.425796
# 14012            296.0             0.520745             0.520694
# 14013            296.0             0.579252             0.581098
#
#        Residuals (10^-6 cm^-1)      QF  Background  CIA (cm-1)
# 0                     0.000289  4988.0         0.0         0.0
# 1                     0.000437  4988.0         0.0         0.0
# 2                     0.000048  4988.0         0.0         0.0
# 3                     0.001339  4988.0         0.0         0.0
# 4                     0.000426  4988.0         0.0         0.0
# ...                        ...     ...         ...         ...
# 14009                -0.001054  5741.0         0.0         0.0
# 14010                -0.000163  5741.0         0.0         0.0
# 14011                 0.002055  5741.0         0.0         0.0
# 14012                 0.000051  5741.0         0.0         0.0
# 14013                -0.001847  5741.0         0.0         0.0
#
# [14014 rows x 11 columns]

# %%
fig, ax = plt.subplots(figsize = [10,5])
ILS = ['RECTANGULAR', 'TRIANGULAR', 'GAUSSIAN', 'DISPERSION', 'COSINUS', 'DIFFRACTION', 'MICHELSON']
molefraction = [result.params['molefraction_CO2_1_1'].value, result.params['molefraction_CO2_2_1'].value, 
               result.params['molefraction_CO2_3_1'].value, result.params['molefraction_CO2_4_1'].value, 
               result.params['molefraction_CO2_5_1'].value, result.params['molefraction_CO2_6_1'].value, 
               result.params['molefraction_CO2_7_1'].value]
molefraction_unc= [result.params['molefraction_CO2_1_1'].stderr, result.params['molefraction_CO2_2_1'].stderr, 
               result.params['molefraction_CO2_3_1'].stderr, result.params['molefraction_CO2_4_1'].stderr, 
               result.params['molefraction_CO2_5_1'].stderr, result.params['molefraction_CO2_6_1'].stderr, 
               result.params['molefraction_CO2_7_1'].stderr]
ax.bar(ILS, 100*(np.asarray(molefraction) - 0.01) / 0.01,yerr = 100*np.asarray(molefraction_unc) / np.asarray(molefraction) , align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Bias in Fit Mole Fraction (%)')
ax.set_xlabel('ILS Function')
plt.show()
