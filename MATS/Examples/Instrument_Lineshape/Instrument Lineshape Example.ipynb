# %% [markdown]
# # Instrument Lineshapes
#
# MATS has added the capability to simulate and fit spectra using an instrument lineshape.  MATS automatically loads the slit functions defined in HAPI, but could use any slit function with the form slit_function(x, resolution) or slit_function(x, [resolutions]).  MATS uses a slight variation of the HAPI convolveSpectrumSame, where the arange_ function was redefined to address a integer/float bug in the underlying np.linspace call.  This implementation currently assumes an equal wavenumber spacing.
#
# The example below simulates the same spectrum and applies the different HAPI instrument line shapes.  The simulated molefraction is perturbted and then floated during a fit.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
from scipy import interpolate
import seaborn as sns

sys.path.append(r'C:\Users\ema3\Documents\MATS\MATS')# set location of HAPI.py module
# %matplotlib inline
from MATS import *
# Out:
# HAPI version: 1.1.1.0
# To get the most up-to-date version please check http://hitran.org/hapi
# ATTENTION: Python versions of partition sums from TIPS-2017 are now available in HAPI code
#
#            It is free to use HAPI. If you use HAPI in your research or software development,
#            please cite it using the following reference:
#            R.V. Kochanov, I.E. Gordon, L.S. Rothman, P. Wcislo, C. Hill, J.S. Wilzewski,
#            HITRAN Application Programming Interface (HAPI): A comprehensive approach
#            to working with spectroscopic data, J. Quant. Spectrosc. Radiat. Transfer 177, 15-30 (2016)
#            DOI: 10.1016/j.jqsrt.2016.03.005

# %% [markdown]
# ## Simulate Spectra with ILS
#
# The spectrum object definitions show how to use the ILS_function, ILS_resolution, and ILS_wing (defines the length of the ILS slit function to use in the convolution, such that the length is +/- ILS_wing / spectrum stepsize) to define the ILS function.  The outputs below show the generated spectrum for each ILS_function

# %%
# Shared Simulation and Fit Parameters
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
Fit_Intensity = 1e-24#intensities must be above this value for the line to be fit
wave_range = 1.5 #range outside of experimental x-range to simulate
IntensityThreshold = 1e-30 #intensities must be above this value to be simulated
segment_column = None
order_baseline_fit = 1
etalon = {}
SNR = 5000
resolution = 0.25
molefraction = {2:0.01}
wave_min = 6320
wave_max = 6340
wave_step = 0.01


linelist = r'C:\Users\ema3\Documents\MATS\MATS\Linelists' # Location of the Summary Data File
os.chdir(linelist)
PARAM_LINELIST = pd.read_csv('CO2_30012.csv')
PARAM_LINELIST = PARAM_LINELIST[(PARAM_LINELIST['nu'] <= wave_max + wave_range) & (PARAM_LINELIST['nu']>= wave_min - wave_step)]

path = r'C:\Users\ema3\Documents\MATS\MATS\Examples\Instrument_Lineshape' # Location of the Summary Data File
os.chdir(path)

# Simulate Spectra
spec_rectangular =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Rectangular', 
                               molefraction =  {2:0.01} , ILS_function = SLIT_RECTANGULAR, ILS_resolution = resolution, ILS_wing = 10)
spec_triangular=  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Triangular', 
                               molefraction =  {2:0.01}, ILS_function = SLIT_TRIANGULAR, ILS_resolution = resolution, ILS_wing = 10)
spec_gaussian =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Gaussian', 
                               molefraction =  {2:0.01}, ILS_function = SLIT_GAUSSIAN, ILS_resolution = resolution, ILS_wing = 10)
spec_dispersion =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Dispersion', 
                               molefraction =  {2:0.01}, ILS_function = SLIT_DISPERSION, ILS_resolution = resolution, ILS_wing = 10)
spec_cosinus =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Cosinus', 
                               molefraction =  {2:0.01}, ILS_function = SLIT_COSINUS, ILS_resolution = resolution, ILS_wing = 10)
spec_diffraction =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Diffraction', 
                               molefraction =  {2:0.01}, ILS_function = SLIT_DIFFRACTION, ILS_resolution = resolution, ILS_wing = 10)
spec_michelson =  simulate_spectrum(PARAM_LINELIST, wave_min, wave_max, wave_step,
                                SNR = SNR, baseline_terms = [0], temperature = 22.85,  
                                pressure = 150, 
                                 filename = 'Michelson', 
                               molefraction =  {2:0.01}, ILS_function = SLIT_MICHELSON, ILS_resolution = resolution, ILS_wing = 10)
print ('Rectangular')
spec_rectangular.plot_wave_alpha()
print ('Triangular')
spec_triangular.plot_wave_alpha()
print ('Gaussian')
spec_gaussian.plot_wave_alpha()
print ('Dispersion')
spec_dispersion.plot_wave_alpha()
print ('Cosinus')
spec_cosinus.plot_wave_alpha()
print ('Diffraction')
spec_diffraction.plot_wave_alpha()
print ('Michelson')
spec_michelson.plot_wave_alpha()
# Out:
# Rectangular
# Triangular
# Gaussian
# Dispersion
# Cosinus
# Diffraction
# Michelson

# %% [markdown]
# ## Generate Fit Parameters
#
# The CO2 molefraction is perturbed from the initial guess. Normally distributed 2% random uncertainy put on the initial mole fraction guess.
#
# In addition to the normal line shape and baseline parameters the ILS resolution parameters are also fittable parameters.  This is also coded in such a way that different spectra can have different ILS functions and the baseline linelist table adequately accounts for this.  While floating the resolution parameters is possible, it should be done with caution as all other parameters are dependent on this value, so correlation and poor fits are likely.

# %%
SPECTRA = Dataset([ spec_rectangular, spec_triangular, spec_gaussian, spec_dispersion, spec_cosinus, 
                               spec_diffraction, spec_michelson],  'ILS Study', PARAM_LINELIST) 
BASE_LINELIST = SPECTRA.generate_baseline_paramlist()

BASE_LINELIST['molefraction_CO2'] = BASE_LINELIST['molefraction_CO2'].values*(1 + np.random.normal(loc = 0, scale =1, size = len(BASE_LINELIST['molefraction_CO2']))*(2/100)) #Adjust the mole fraction of each sample by a mole fraction of random value normally distributed 2%




FITPARAMS = Generate_FitParam_File(SPECTRA, PARAM_LINELIST, BASE_LINELIST,
                                           lineprofile = 'SDNGP', linemixing = True, 
                                              fit_intensity = Fit_Intensity, threshold_intensity = IntensityThreshold, 
                                              nu_constrain = True, sw_constrain = True, gamma0_constrain = True, delta0_constrain = True, 
                                               aw_constrain = True, as_constrain = True, 
                                               nuVC_constrain = True, eta_constrain =True, linemixing_constrain = True) 


FITPARAMS.generate_fit_param_linelist_from_linelist(vary_nu = {2:{1:False, 2:False, 3:False}}, vary_sw = {2:{1:False, 2:False, 3:False}},
                                                    vary_gamma0 = {2:{1: False, 2:False, 3: False}}, vary_n_gamma0 = {2:{1:False}}, 
                                                    vary_delta0 = {2:{1:False, 2:False, 3: False}}, vary_n_delta0 = {2:{1:False}}, 
                                                    vary_aw = {2:{1: False, 2:False, 3: False}}, vary_n_gamma2 = {2:{1:False}}, 
                                                    vary_as = {2:{1:False}}, vary_n_delta2 = {2:{1:False}}, 
                                                    vary_nuVC = {2:{1:False}}, vary_n_nuVC = {2:{1:False}},
                                                    vary_eta = {}, vary_linemixing = {2:{1:False}})

FITPARAMS.generate_fit_baseline_linelist(vary_baseline = False, vary_molefraction = {2:True}, vary_ILS_res = False)
# Out:
#                  Segment Number  Pressure  Pressure_err  Pressure_vary  \
# Spectrum Number
# 1.0                         0.0  0.197368             0          False
# 2.0                         0.0  0.197368             0          False
# 3.0                         0.0  0.197368             0          False
# 4.0                         0.0  0.197368             0          False
# 5.0                         0.0  0.197368             0          False
# 6.0                         0.0  0.197368             0          False
# 7.0                         0.0  0.197368             0          False
#
#                  SLIT_COSINUS_res_0  SLIT_COSINUS_res_0_err  \
# Spectrum Number
# 1.0                            0.00                       0
# 2.0                            0.00                       0
# 3.0                            0.00                       0
# 4.0                            0.00                       0
# 5.0                            0.25                       0
# 6.0                            0.00                       0
# 7.0                            0.00                       0
#
#                  SLIT_COSINUS_res_0_vary  SLIT_DIFFRACTION_res_0  \
# Spectrum Number
# 1.0                                False                    0.00
# 2.0                                False                    0.00
# 3.0                                False                    0.00
# 4.0                                False                    0.00
# 5.0                                False                    0.00
# 6.0                                False                    0.25
# 7.0                                False                    0.00
#
#                  SLIT_DIFFRACTION_res_0_err  SLIT_DIFFRACTION_res_0_vary  ...  \
# Spectrum Number                                                           ...
# 1.0                                       0                        False  ...
# 2.0                                       0                        False  ...
# 3.0                                       0                        False  ...
# 4.0                                       0                        False  ...
# 5.0                                       0                        False  ...
# 6.0                                       0                        False  ...
# 7.0                                       0                        False  ...
#
#                  Temperature_vary  baseline_a  baseline_a_err  \
# Spectrum Number
# 1.0                         False         0.0               0
# 2.0                         False         0.0               0
# 3.0                         False         0.0               0
# 4.0                         False         0.0               0
# 5.0                         False         0.0               0
# 6.0                         False         0.0               0
# 7.0                         False         0.0               0
#
#                  baseline_a_vary  molefraction_CO2  molefraction_CO2_err  \
# Spectrum Number
# 1.0                        False          0.010106                     0
# 2.0                        False          0.010189                     0
# 3.0                        False          0.009882                     0
# 4.0                        False          0.010110                     0
# 5.0                        False          0.009846                     0
# 6.0                        False          0.009938                     0
# 7.0                        False          0.010292                     0
#
#                  molefraction_CO2_vary  x_shift  x_shift_err  x_shift_vary
# Spectrum Number
# 1.0                               True      0.0            0         False
# 2.0                               True      0.0            0         False
# 3.0                               True      0.0            0         False
# 4.0                               True      0.0            0         False
# 5.0                               True      0.0            0         False
# 6.0                               True      0.0            0         False
# 7.0                               True      0.0            0         False
#
# [7 rows x 37 columns]

# %% [markdown]
# # Fit Data

# %%
fit_data = Fit_DataSet(SPECTRA,'Baseline_LineList', 'Parameter_LineList', minimum_parameter_fit_intensity = Fit_Intensity)
params = fit_data.generate_params()
for param in params:
    if ('_res_' in param) and (params[param].vary == True):
        params[param].set(min = 0.01)
        
result = fit_data.fit_data(params)
print (result.params.pretty_print())
fit_data.residual_analysis(result, indv_resid_plot=True)
fit_data.update_params(result)
SPECTRA.generate_summary_file(save_file = True)
# Out:
# Name                           Value      Min      Max   Stderr     Vary     Expr Brute_Step
# Pressure_1_0                  0.1974     -inf      inf        0    False     None     None
# Pressure_2_0                  0.1974     -inf      inf        0    False     None     None
# Pressure_3_0                  0.1974     -inf      inf        0    False     None     None
# Pressure_4_0                  0.1974     -inf      inf        0    False     None     None
# Pressure_5_0                  0.1974     -inf      inf        0    False     None     None
# Pressure_6_0                  0.1974     -inf      inf        0    False     None     None
# Pressure_7_0                  0.1974     -inf      inf        0    False     None     None
# SD_delta_air_line_101              0     -inf      inf        0    False     None     None
# SD_delta_air_line_156              0     -inf      inf        0    False     None     None
# SD_delta_air_line_204              0     -inf      inf        0    False     None     None
# SD_delta_air_line_252              0     -inf      inf        0    False     None     None
# SD_delta_air_line_304              0     -inf      inf        0    False     None     None
# SD_delta_air_line_350              0     -inf      inf        0    False     None     None
# SD_delta_air_line_38               0     -inf      inf        0    False     None     None
# SD_delta_air_line_396              0     -inf      inf        0    False     None     None
# SD_delta_air_line_441              0     -inf      inf        0    False     None     None
# SD_delta_air_line_487              0     -inf      inf        0    False     None     None
# SD_delta_air_line_539              0     -inf      inf        0    False     None     None
# SD_delta_air_line_588              0     -inf      inf        0    False     None     None
# SD_gamma_air_line_101        0.06088     -inf      inf        0    False     None     None
# SD_gamma_air_line_156        0.05559     -inf      inf        0    False     None     None
# SD_gamma_air_line_204        0.07412     -inf      inf        0    False     None     None
# SD_gamma_air_line_252        0.07147     -inf      inf        0    False     None     None
# SD_gamma_air_line_304        0.07147     -inf      inf        0    False     None     None
# SD_gamma_air_line_350        0.06883     -inf      inf        0    False     None     None
# SD_gamma_air_line_38         0.06883     -inf      inf        0    False     None     None
# SD_gamma_air_line_396        0.07677     -inf      inf        0    False     None     None
# SD_gamma_air_line_441        0.07941     -inf      inf        0    False     None     None
# SD_gamma_air_line_487        0.08206     -inf      inf        0    False     None     None
# SD_gamma_air_line_539        0.07941     -inf      inf        0    False     None     None
# SD_gamma_air_line_588        0.07941     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_1_0             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_2_0             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_3_0             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_4_0             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_5_0          0.25     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_6_0             0     -inf      inf        0    False     None     None
# SLIT_COSINUS_res_0_7_0             0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_1_0         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_2_0         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_3_0         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_4_0         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_5_0         0     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_6_0      0.25     -inf      inf        0    False     None     None
# SLIT_DIFFRACTION_res_0_7_0         0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_1_0          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_2_0          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_3_0          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_4_0       0.25     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_5_0          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_6_0          0     -inf      inf        0    False     None     None
# SLIT_DISPERSION_res_0_7_0          0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_1_0            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_2_0            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_3_0         0.25     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_4_0            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_5_0            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_6_0            0     -inf      inf        0    False     None     None
# SLIT_GAUSSIAN_res_0_7_0            0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_1_0           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_2_0           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_3_0           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_4_0           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_5_0           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_6_0           0     -inf      inf        0    False     None     None
# SLIT_MICHELSON_res_0_7_0        0.25     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_1_0      0.25     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_2_0         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_3_0         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_4_0         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_5_0         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_6_0         0     -inf      inf        0    False     None     None
# SLIT_RECTANGULAR_res_0_7_0         0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_1_0          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_2_0       0.25     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_3_0          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_4_0          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_5_0          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_6_0          0     -inf      inf        0    False     None     None
# SLIT_TRIANGULAR_res_0_7_0          0     -inf      inf        0    False     None     None
# Temperature_1_0                  296     -inf      inf        0    False     None     None
# Temperature_2_0                  296     -inf      inf        0    False     None     None
# Temperature_3_0                  296     -inf      inf        0    False     None     None
# Temperature_4_0                  296     -inf      inf        0    False     None     None
# Temperature_5_0                  296     -inf      inf        0    False     None     None
# Temperature_6_0                  296     -inf      inf        0    False     None     None
# Temperature_7_0                  296     -inf      inf        0    False     None     None
# baseline_a_1_0                     0     -inf      inf        0    False     None     None
# baseline_a_2_0                     0     -inf      inf        0    False     None     None
# baseline_a_3_0                     0     -inf      inf        0    False     None     None
# baseline_a_4_0                     0     -inf      inf        0    False     None     None
# baseline_a_5_0                     0     -inf      inf        0    False     None     None
# baseline_a_6_0                     0     -inf      inf        0    False     None     None
# baseline_a_7_0                     0     -inf      inf        0    False     None     None
# delta0_air_line_101         -0.006489     -inf      inf        0    False     None     None
# delta0_air_line_156         -0.006286     -inf      inf        0    False     None     None
# delta0_air_line_204         -0.006388     -inf      inf        0    False     None     None
# delta0_air_line_252         -0.007098     -inf      inf        0    False     None     None
# delta0_air_line_304         -0.006591     -inf      inf        0    False     None     None
# delta0_air_line_350         -0.006286     -inf      inf        0    False     None     None
# delta0_air_line_38          -0.006793     -inf      inf        0    False     None     None
# delta0_air_line_396         -0.006185     -inf      inf        0    False     None     None
# delta0_air_line_441         -0.006084     -inf      inf        0    False     None     None
# delta0_air_line_487         -0.006016     -inf      inf        0    False     None     None
# delta0_air_line_539         -0.005813     -inf      inf        0    False     None     None
# delta0_air_line_588         -0.005408     -inf      inf        0    False     None     None
# eta_air_line_101                   0     -inf      inf        0    False     None     None
# eta_air_line_156                   0     -inf      inf        0    False     None     None
# eta_air_line_204                   0     -inf      inf        0    False     None     None
# eta_air_line_252                   0     -inf      inf        0    False     None     None
# eta_air_line_304                   0     -inf      inf        0    False     None     None
# eta_air_line_350                   0     -inf      inf        0    False     None     None
# eta_air_line_38                    0     -inf      inf        0    False     None     None
# eta_air_line_396                   0     -inf      inf        0    False     None     None
# eta_air_line_441                   0     -inf      inf        0    False     None     None
# eta_air_line_487                   0     -inf      inf        0    False     None     None
# eta_air_line_539                   0     -inf      inf        0    False     None     None
# eta_air_line_588                   0     -inf      inf        0    False     None     None
# gamma0_air_line_101           0.0706     -inf      inf        0    False     None     None
# gamma0_air_line_156          0.07071     -inf      inf        0    False     None     None
# gamma0_air_line_204          0.07142     -inf      inf        0    False     None     None
# gamma0_air_line_252          0.07199     -inf      inf        0    False     None     None
# gamma0_air_line_304          0.07311     -inf      inf        0    False     None     None
# gamma0_air_line_350          0.07429     -inf      inf        0    False     None     None
# gamma0_air_line_38           0.06979     -inf      inf        0    False     None     None
# gamma0_air_line_396          0.07581     -inf      inf        0    False     None     None
# gamma0_air_line_441          0.07689     -inf      inf        0    False     None     None
# gamma0_air_line_487          0.07889     -inf      inf        0    False     None     None
# gamma0_air_line_539           0.0803     -inf      inf        0    False     None     None
# gamma0_air_line_588          0.08179     -inf      inf        0    False     None     None
# molefraction_CO2_1_0            0.01     -inf      inf 1.583e-07     True     None     None
# molefraction_CO2_2_0            0.01     -inf      inf 1.817e-07     True     None     None
# molefraction_CO2_3_0            0.01     -inf      inf 1.822e-07     True     None     None
# molefraction_CO2_4_0            0.01     -inf      inf 2.477e-07     True     None     None
# molefraction_CO2_5_0            0.01     -inf      inf 4.778e-07     True     None     None
# molefraction_CO2_6_0            0.01     -inf      inf 1.832e-07     True     None     None
# molefraction_CO2_7_0            0.01     -inf      inf 1.169e-07     True     None     None
# nuVC_air_line_101           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_156           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_204           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_252           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_304           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_350           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_38            0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_396           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_441           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_487           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_539           0.003099     -inf      inf        0    False     None     None
# nuVC_air_line_588           0.003099     -inf      inf        0    False     None     None
# nu_line_101                     6323     -inf      inf        0    False     None     None
# nu_line_156                     6325     -inf      inf        0    False     None     None
# nu_line_204                     6327     -inf      inf        0    False     None     None
# nu_line_252                     6329     -inf      inf        0    False     None     None
# nu_line_304                     6331     -inf      inf        0    False     None     None
# nu_line_350                     6333     -inf      inf        0    False     None     None
# nu_line_38                      6321     -inf      inf        0    False     None     None
# nu_line_396                     6334     -inf      inf        0    False     None     None
# nu_line_441                     6336     -inf      inf        0    False     None     None
# nu_line_487                     6338     -inf      inf        0    False     None     None
# nu_line_539                     6340     -inf      inf        0    False     None     None
# nu_line_588                     6341     -inf      inf        0    False     None     None
# sw_line_101                     9.94     -inf      inf        0    False     None     None
# sw_line_156                     11.4     -inf      inf        0    False     None     None
# sw_line_204                     12.9     -inf      inf        0    False     None     None
# sw_line_252                     14.1     -inf      inf        0    False     None     None
# sw_line_304                     15.2     -inf      inf        0    False     None     None
# sw_line_350                     15.9     -inf      inf        0    False     None     None
# sw_line_38                      8.47     -inf      inf        0    False     None     None
# sw_line_396                     16.2     -inf      inf        0    False     None     None
# sw_line_441                       16     -inf      inf        0    False     None     None
# sw_line_487                     15.2     -inf      inf        0    False     None     None
# sw_line_539                     13.9     -inf      inf        0    False     None     None
# sw_line_588                       12     -inf      inf        0    False     None     None
# x_shift_1_0                        0     -inf      inf        0    False     None     None
# x_shift_2_0                        0     -inf      inf        0    False     None     None
# x_shift_3_0                        0     -inf      inf        0    False     None     None
# x_shift_4_0                        0     -inf      inf        0    False     None     None
# x_shift_5_0                        0     -inf      inf        0    False     None     None
# x_shift_6_0                        0     -inf      inf        0    False     None     None
# x_shift_7_0                        0     -inf      inf        0    False     None     None
# y_air_296_line_101                 0     -inf      inf        0    False     None     None
# y_air_296_line_156                 0     -inf      inf        0    False     None     None
# y_air_296_line_204                 0     -inf      inf        0    False     None     None
# y_air_296_line_252                 0     -inf      inf        0    False     None     None
# y_air_296_line_304                 0     -inf      inf        0    False     None     None
# y_air_296_line_350                 0     -inf      inf        0    False     None     None
# y_air_296_line_38                  0     -inf      inf        0    False     None     None
# y_air_296_line_396                 0     -inf      inf        0    False     None     None
# y_air_296_line_441                 0     -inf      inf        0    False     None     None
# y_air_296_line_487                 0     -inf      inf        0    False     None     None
# y_air_296_line_539                 0     -inf      inf        0    False     None     None
# y_air_296_line_588                 0     -inf      inf        0    False     None     None
# None
#       Spectrum Number Spectrum Name  Frequency (MHz)  Wavenumber (cm-1)  \
# 0                   1   Rectangular     1.894688e+08            6320.00
# 1                   1   Rectangular     1.894691e+08            6320.01
# 2                   1   Rectangular     1.894694e+08            6320.02
# 3                   1   Rectangular     1.894697e+08            6320.03
# 4                   1   Rectangular     1.894700e+08            6320.04
# ...               ...           ...              ...                ...
# 1997                7     Michelson     1.900675e+08            6339.97
# 1998                7     Michelson     1.900678e+08            6339.98
# 1999                7     Michelson     1.900681e+08            6339.99
# 2000                7     Michelson     1.900684e+08            6340.00
# 2001                7     Michelson     1.900687e+08            6340.01
#
#       Pressure (Torr)  Temperature (C)     Tau (us)  Tau Error (%)  \
# 0               150.0            22.85  1118.628809       0.017891
# 1               150.0            22.85   942.160467       0.023726
# 2               150.0            22.85   895.902366       0.013740
# 3               150.0            22.85   815.764016       0.016564
# 4               150.0            22.85   790.834782       0.013740
# ...               ...              ...          ...            ...
# 1997            150.0            22.85   230.411910       0.013559
# 1998            150.0            22.85   113.503921       0.013559
# 1999            150.0            22.85    80.082635       0.013559
# 2000            150.0            22.85    64.935225       0.008084
# 2001            150.0            22.85    58.272088       0.013559
#
#       Alpha (ppm/cm)  Model (ppm/cm)  Residuals (ppm/cm)      QF  Background  \
# 0           0.029819        0.029280           -0.000539  4991.0         0.0
# 1           0.035404        0.034689           -0.000715  4991.0         0.0
# 2           0.037232        0.038147            0.000914  4991.0         0.0
# 3           0.040890        0.040391           -0.000499  4991.0         0.0
# 4           0.042179        0.042476            0.000297  4991.0         0.0
# ...              ...             ...                 ...     ...         ...
# 1997        0.144769        0.145871            0.001103  5788.0         0.0
# 1998        0.293879        0.294389            0.000510  5788.0         0.0
# 1999        0.416525        0.418874            0.002349  5788.0         0.0
# 2000        0.513687        0.513233           -0.000454  5788.0         0.0
# 2001        0.572425        0.573410            0.000985  5788.0         0.0
#
#       CIA (ppm/cm)
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1997             0
# 1998             0
# 1999             0
# 2000             0
# 2001             0
#
# [14014 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize = [10,5])
ILS = ['RECTANGULAR', 'TRIANGULAR', 'GAUSSIAN', 'DISPERSION', 'COSINUS', 'DIFFRACTION', 'MICHELSON']
molefraction = [result.params['molefraction_CO2_1_0'].value, result.params['molefraction_CO2_2_0'].value, 
               result.params['molefraction_CO2_3_0'].value, result.params['molefraction_CO2_4_0'].value, 
               result.params['molefraction_CO2_5_0'].value, result.params['molefraction_CO2_6_0'].value, 
               result.params['molefraction_CO2_7_0'].value]
molefraction_unc= [result.params['molefraction_CO2_1_0'].stderr, result.params['molefraction_CO2_2_0'].stderr, 
               result.params['molefraction_CO2_3_0'].stderr, result.params['molefraction_CO2_4_0'].stderr, 
               result.params['molefraction_CO2_5_0'].stderr, result.params['molefraction_CO2_6_0'].stderr, 
               result.params['molefraction_CO2_7_0'].stderr]
ax.bar(ILS, 100*(np.asarray(molefraction) - 0.01) / 0.01,yerr = 100*np.asarray(molefraction_unc) / np.asarray(molefraction) , align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Bias in Fit Mole Fraction (%)')
ax.set_xlabel('ILS Function')
# Out:
# Text(0.5, 0, 'ILS Function')
